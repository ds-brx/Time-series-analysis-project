# %% [markdown]
# # INTRODUCTION<BR>
#
# Time-series forcasting is one of most exciting fields of application in the domain of data science. It has endless supply of problems from various topics of interest, such as - in finance, forcasting stock prices and trend behavior overtime, global issues such as forcasting unemployement in each quater, also in medical- number of babies born every minutes, number of new cases under a pandemic, to name a few. <br>
# <br>
#     This is a notebook i am trying to develop  in an effort to learn the tools and methods of time-series data analytics and forcasting. Hence, this is a work in progress kernel. <br>
#
# I refer the following resources:
# 1. An excellent book for understanding the concepts:<br> https://machinelearningmastery.com/introduction-to-time-series-forecasting-with-python/<br>
# 2. A number of Kaggle notebooks, i found very helpful:<br>
#     https://www.kaggle.com/jagangupta/time-series-basics-exploring-traditional-ts<br>
#     https://www.kaggle.com/jayitabhattacharyya/facebook-s-neural-prophet<br>
#     https://www.kaggle.com/parulpandey/getting-started-with-time-series-using-pandas<br>
#     https://www.kaggle.com/thebrownviking20/everything-you-can-do-with-a-time-series

# %% [markdown]
# # Importing tools

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/nifty50-stock-market-data/HDFCBANK.csv
# /kaggle/input/nifty50-stock-market-data/GRASIM.csv
# /kaggle/input/nifty50-stock-market-data/WIPRO.csv
# /kaggle/input/nifty50-stock-market-data/stock_metadata.csv
# /kaggle/input/nifty50-stock-market-data/BPCL.csv
# /kaggle/input/nifty50-stock-market-data/INFY.csv
# /kaggle/input/nifty50-stock-market-data/LT.csv
# /kaggle/input/nifty50-stock-market-data/RELIANCE.csv
# /kaggle/input/nifty50-stock-market-data/BRITANNIA.csv
# /kaggle/input/nifty50-stock-market-data/INFRATEL.csv
# /kaggle/input/nifty50-stock-market-data/HEROMOTOCO.csv
# /kaggle/input/nifty50-stock-market-data/HINDUNILVR.csv
# /kaggle/input/nifty50-stock-market-data/TATAMOTORS.csv
# /kaggle/input/nifty50-stock-market-data/MM.csv
# /kaggle/input/nifty50-stock-market-data/HDFC.csv
# /kaggle/input/nifty50-stock-market-data/JSWSTEEL.csv
# /kaggle/input/nifty50-stock-market-data/TITAN.csv
# /kaggle/input/nifty50-stock-market-data/HINDALCO.csv
# /kaggle/input/nifty50-stock-market-data/AXISBANK.csv
# /kaggle/input/nifty50-stock-market-data/HCLTECH.csv
# /kaggle/input/nifty50-stock-market-data/ADANIPORTS.csv
# /kaggle/input/nifty50-stock-market-data/GAIL.csv
# /kaggle/input/nifty50-stock-market-data/NIFTY50_all.csv
# /kaggle/input/nifty50-stock-market-data/BAJAJFINSV.csv
# /kaggle/input/nifty50-stock-market-data/BAJFINANCE.csv
# /kaggle/input/nifty50-stock-market-data/ICICIBANK.csv
# /kaggle/input/nifty50-stock-market-data/ZEEL.csv
# /kaggle/input/nifty50-stock-market-data/ASIANPAINT.csv
# /kaggle/input/nifty50-stock-market-data/IOC.csv
# /kaggle/input/nifty50-stock-market-data/TATASTEEL.csv
# /kaggle/input/nifty50-stock-market-data/COALINDIA.csv
# /kaggle/input/nifty50-stock-market-data/NESTLEIND.csv
# /kaggle/input/nifty50-stock-market-data/DRREDDY.csv
# /kaggle/input/nifty50-stock-market-data/ONGC.csv
# /kaggle/input/nifty50-stock-market-data/EICHERMOT.csv
# /kaggle/input/nifty50-stock-market-data/UPL.csv
# /kaggle/input/nifty50-stock-market-data/SUNPHARMA.csv
# /kaggle/input/nifty50-stock-market-data/ULTRACEMCO.csv
# /kaggle/input/nifty50-stock-market-data/CIPLA.csv
# /kaggle/input/nifty50-stock-market-data/SHREECEM.csv
# /kaggle/input/nifty50-stock-market-data/VEDL.csv
# /kaggle/input/nifty50-stock-market-data/TCS.csv
# /kaggle/input/nifty50-stock-market-data/NTPC.csv
# /kaggle/input/nifty50-stock-market-data/MARUTI.csv
# /kaggle/input/nifty50-stock-market-data/KOTAKBANK.csv
# /kaggle/input/nifty50-stock-market-data/ITC.csv
# /kaggle/input/nifty50-stock-market-data/BAJAJ-AUTO.csv
# /kaggle/input/nifty50-stock-market-data/SBIN.csv
# /kaggle/input/nifty50-stock-market-data/INDUSINDBK.csv
# /kaggle/input/nifty50-stock-market-data/BHARTIARTL.csv
# /kaggle/input/nifty50-stock-market-data/TECHM.csv
# /kaggle/input/nifty50-stock-market-data/POWERGRID.csv

# %%
import numpy as np 
import pandas as pd
import lightgbm as lgb
from numpy.random import normal, seed
import math
from sklearn.metrics import mean_squared_error

from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
from matplotlib import pyplot
from pylab import rcParams
from plotly import tools
import plotly.graph_objs as go
import plotly.figure_factory as ff
import seaborn as sns

import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.distributions.empirical_distribution import ECDF
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from scipy.stats import norm
import scipy.stats as scs

from fbprophet import Prophet
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# Dataset: This includes the stock data of Nifty-50 index from NSE (National Stock Exchange) India over the last 20 years (2000 - 2019). I am going to explore the stock market data of ICICI bank.

# %%
df = pd.read_csv("../input/nifty50-stock-market-data/ICICIBANK.csv", parse_dates=["Date"],index_col="Date")
df.head()
# Out:
#                Symbol Series  Prev Close   Open   High    Low   Last  Close  \
# Date
# 2000-01-03  ICICIBANK     EQ       69.20  74.35  74.75  71.40  74.75  74.75
# 2000-01-04  ICICIBANK     EQ       74.75  73.05  78.50  71.00  73.25  73.05
# 2000-01-05  ICICIBANK     EQ       73.05  70.00  73.50  67.50  70.00  69.50
# 2000-01-06  ICICIBANK     EQ       69.50  71.00  74.00  69.55  69.75  70.05
# 2000-01-07  ICICIBANK     EQ       70.05  69.00  72.50  66.00  67.00  67.40
#
#              VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2000-01-03  73.20  286260  2.095439e+12     NaN                 NaN
# 2000-01-04  73.38  296264  2.173893e+12     NaN                 NaN
# 2000-01-05  70.85  227624  1.612794e+12     NaN                 NaN
# 2000-01-06  72.04  275149  1.982121e+12     NaN                 NaN
# 2000-01-07  68.72  138809  9.538882e+11     NaN                 NaN
#
#             %Deliverble
# Date
# 2000-01-03          NaN
# 2000-01-04          NaN
# 2000-01-05          NaN
# 2000-01-06          NaN
# 2000-01-07          NaN

# %%
df.tail()
# Out:
#                Symbol Series  Prev Close   Open    High    Low   Last   Close  \
# Date
# 2020-11-23  ICICIBANK     EQ      480.20  481.8  483.35  466.5  468.3  468.25
# 2020-11-24  ICICIBANK     EQ      468.25  474.0  480.00  471.2  479.0  478.20
# 2020-11-25  ICICIBANK     EQ      478.20  485.0  489.95  471.1  472.2  472.70
# 2020-11-26  ICICIBANK     EQ      472.70  475.1  477.20  465.8  477.0  475.30
# 2020-11-27  ICICIBANK     EQ      475.30  476.4  479.55  471.3  474.3  473.35
#
#               VWAP    Volume      Turnover    Trades  Deliverable Volume  \
# Date
# 2020-11-23  472.40  29513544  1.394225e+15  303018.0          11243809.0
# 2020-11-24  475.60  23135994  1.100354e+15  240284.0           9426987.0
# 2020-11-25  481.71  34168305  1.645916e+15  309210.0           9933859.0
# 2020-11-26  471.79  28707911  1.354423e+15  279104.0           9365527.0
# 2020-11-27  474.84  48390771  2.297771e+15  223863.0          30805507.0
#
#             %Deliverble
# Date
# 2020-11-23       0.3810
# 2020-11-24       0.4075
# 2020-11-25       0.2907
# 2020-11-26       0.3262
# 2020-11-27       0.6366

# %% [markdown]
# # Features:
# 1. Series: Here EQ stands for equity series of stock market.
# 2. Prev Close: The closing price of the stock for the day before.
# 3. Open,High, Low, Last, Close: The opening price, highest price, lowest price, last price and closing price of ICICI shares on the current day.
# 4. **VWAP**: Volume Weighted Average Price,the **target variable** to predict. VWAP is a trading benchmark used by traders that gives the average price the stock has traded at throughout the day, based on both volume and price.
# 5. Volume: Volume of shares traded on the current day.
# 6. Turnover: It is a measure of stock liquidity calculated by dividing the total number of shares traded over a period by the average number of shares outstanding for the period.
# 7. Trades: total number of trades on the current day.
# 8. Deliverable Volume:  is the quantity of shares which actually move from one set of people to another set of people.
# 9. Deliverable(%): Deliverable volume in percentage.

# %% [markdown]
# # Exploring the data
# Let's explore the missing values, trend, seasonality, correlation and noise in the data.

# %%
df.shape
# Out:
# (5204, 14)

# %%
# for feature in df.columns:
#     print("{} : {}".format(feature,df[feature].isna().sum()))
df.isna().sum()
# Out:
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     517
# %Deliverble            517
# dtype: int64

# %% [markdown]
# Trades, Deliverable volume and %Deliverable are the columns with missing values.

# %%
print("Percentage of missing trade values = {:.2f}".format(100*(df['Trades'].isna().sum())/df.shape[0]))
print("Percentage of missing Deliverable Volume values = {:.2f}".format(100*(df['Deliverable Volume'].isna().sum())/df.shape[0]))
print("Percentage of missing %Deliverble values = {:.2f}".format(100*(df['%Deliverble'].isna().sum())/df.shape[0]))
# Out:
# Percentage of missing trade values = 54.77
# Percentage of missing Deliverable Volume values = 9.93
# Percentage of missing %Deliverble values = 9.93

# %% [markdown]
# So more than 50% trade data is missing, while only 10% each of deliverable volume and deliverable% is missing. We can drop the rows where deliverable volume is missing. For trade data, we will visualize it to understand the best statistic for imputation.

# %%
df = df[df['Deliverable Volume'] >0]

# %%
ax = df[['Trades']].plot(figsize=(20, 6))
ax.set_title('Trades', fontsize=24);

# %% [markdown]
# We can see that trade values show a pulse in growth from the period of 2020 - 2021. To fill the NaN values, perhaps the safest option is to forward fill. But since many consecutive rows have missing values, we can fill with mean value.

# %%
df['Trades'].ffill(axis = 0) 
trade_data = df.loc[df.index<='2019']
mean = round(trade_data['Trades'].mean(),1)
df["Trades"].fillna(value = mean,inplace = True)

# %% [markdown]
# # Visualizing trends in stock prices

# %%
ax = df[['Turnover']].plot(figsize=(20, 6))
ax.set_title('Turnover', fontsize=24);

# %%
ax = df[['Volume']].plot(figsize=(20, 6))
ax.set_title('Volume', fontsize=24);

# %% [markdown]
# The volume of shares traded showed a sharp growth during the period of 20-21.

# %%
ax = df[['High', 'Low']].plot(figsize=(20, 6))
ax.set_title('High v/s Low', fontsize=24);

# %%
ax = df[['VWAP']].plot(figsize=(20, 6))
ax.set_title('VWAP', fontsize=24);

# %% [markdown]
# Even though turnover and volume increased during the year 20-21, the prices dropped significantly. This explains the fact that, due to the pandemic
# Covid-19, many investors took the advantage of dropping prices to buy stocks in bulk, perhaps looking forward to sell when industries regain momentum.

# %%
df['VWAP'].resample('A').mean().plot(kind='bar')
plt.title('End of year VWAP for ICICI bank')
# Out:
# Text(0.5, 1.0, 'End of year VWAP for ICICI bank')

# %%
df['VWAP'].resample('AS').mean().plot(kind='bar')
plt.title('Yearly Mean VWAP for ICICI bank')
# Out:
# Text(0.5, 1.0, 'Yearly Mean VWAP for ICICI bank')

# %%
df['VWAP']['2010'].resample('M').mean().plot(kind='bar')
plt.title('Monthly Mean 2010 VWAP for ICICI bank')
# Out:
# Text(0.5, 1.0, 'Monthly Mean 2010 VWAP for ICICI bank')

# %%
df['VWAP']['2015'].resample('M').mean().plot(kind='bar')
plt.title('Monthly Mean 2015 VWAP for ICICI bank')
# Out:
# Text(0.5, 1.0, 'Monthly Mean 2015 VWAP for ICICI bank')

# %%
df['VWAP']['2020'].resample('M').mean().plot(kind='bar')
plt.title('Monthly Mean 2020 VWAP for ICICI bank')
# Out:
# Text(0.5, 1.0, 'Monthly Mean 2020 VWAP for ICICI bank')

# %% [markdown]
# VWAP has decreased on average in a decade(2010-2020).

# %% [markdown]
# Box-Cox Transformation - to generate a uniform distribution.

# %%
from scipy.stats import boxcox
df['vwap_boxcox'],lam = boxcox(df['VWAP'])
print('Lambda: %f' % lam)
rcParams['figure.figsize'] = 11, 9
pyplot.figure(1)
# line plot
pyplot.subplot(211)
pyplot.plot(df['vwap_boxcox'])
# histogram
pyplot.subplot(212)
pyplot.hist(df['vwap_boxcox'])
pyplot.show()
# Out:
# Lambda: 0.168186

# %% [markdown]
# # Moving average smoothing
# Smoothing is a technique applied to time series to remove the fine-grained variation between time steps. The hope of smoothing is to remove noise and better expose the signal of the underlying causal processes.
#
# By plotting rolling

# %%
rolling_vwap = df['VWAP'].rolling(window=7)
rolling_vwap_mean = rolling_vwap.mean()
print(rolling_vwap_mean.head(10))
df['VWAP'].plot() 
rolling_vwap_mean.plot(color='blue') 
pyplot.show()

df['VWAP']['2002'].plot() 
rolling_vwap_mean['2002'].plot(color='blue')
plt.title('Lag in VWAP 2002')
pyplot.show()

df['VWAP']['2010'].plot() 
rolling_vwap_mean['2010'].plot(color='blue')
plt.title('Lag in VWAP 2010')
pyplot.show()

df['VWAP']['2015'].plot() 
rolling_vwap_mean['2015'].plot(color='blue')
plt.title('Lag in VWAP 2015')
pyplot.show()

df['VWAP']['2020'].plot() 
rolling_vwap_mean['2020'].plot(color='blue')
plt.title('Lag in VWAP 2020')
pyplot.show()
# Out:
# Date
# 2002-01-01          NaN
# 2002-01-02          NaN
# 2002-01-03          NaN
# 2002-01-04          NaN
# 2002-01-07          NaN
# 2002-01-08          NaN
# 2002-01-09    90.178571
# 2002-01-10    90.625714
# 2002-01-11    91.022857
# 2002-01-14    91.087143
# Name: VWAP, dtype: float64

# %% [markdown]
# # Autocorrelation plot
#
# Autocorrelation - The autocorrelation function (ACF) measures how a series is correlated with itself at different lags.
#  "Correlation values, called correlation coefficients, can be calculated for each observation and different lag values. Once calculated, a plot can be created to help better understand how this relationship changes over the lag. This type of plot is called an autocorrelation plot..." - *Introduction to Time Series Forecasting With Python*, Jason Brownlee.

# %%
plot_acf(df['VWAP'],title="VWAP Autocorrelation")
plt.show()

# %%
autocorrelation_plot(df['VWAP'])
plt.title('VWAP Autocorrelation')
pyplot.show()

# %% [markdown]
# Partial Autocorrelation

# %%
plot_pacf(df['VWAP'],lags=50)
plt.show()

# %% [markdown]
# # Stationarity-
# We'll check with the Augmented Dickey-Fuller test for stationarity in the dataset. A stationary time series is one whose statistical properties such as mean, variance, autocorrelation, etc. are all constant over time.

# %%
result = adfuller(df['VWAP'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1]) 
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -2.694529
# p-value: 0.074990
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# Running the example prints the test statistic value of -2.69. If random, such autocorrelations should be near zero for any and all time-lag separations. If non-random, then one or more of the autocorrelations will be significantly non-zero.The more negative this statistic, the more likely we are to reject the null hypothesis (we have a stationary dataset). Hence the values are relatively not random, but depend on the prior recorded values.

# %% [markdown]
# # Decompose Time Series Data
# > "Time series decomposition involves thinking of a series as a combination of level, trend, seasonality, and noise components. Decomposition provides a useful abstract model for thinking about time series generally and for better understanding problems during time series analysis and forecasting."- *Introduction to Time Series Forecasting With Python*, Jason Brownlee.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose 
series = df['VWAP']
result = seasonal_decompose(series, model='additive', period=1) 
rcParams['figure.figsize'] = 11, 9
result.plot()
pyplot.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose 
series = df['VWAP']
result = seasonal_decompose(series, model='multiplicative', period=1) 
rcParams['figure.figsize'] = 11, 9
result.plot()
pyplot.show()

# %%
df2 = df.copy()
df2.head()
# Out:
#                Symbol Series  Prev Close   Open   High    Low   Last  Close  \
# Date
# 2002-01-01  ICICIBANK     EQ        88.7  89.95  89.95  87.30  88.05  88.50
# 2002-01-02  ICICIBANK     EQ        88.5  88.00  89.00  87.50  87.60  88.40
# 2002-01-03  ICICIBANK     EQ        88.4  86.60  92.95  86.60  92.05  92.00
# 2002-01-04  ICICIBANK     EQ        92.0  92.50  93.20  90.00  91.90  91.10
# 2002-01-07  ICICIBANK     EQ        91.1  91.00  92.50  89.25  91.05  90.15
#
#              VWAP  Volume      Turnover    Trades  Deliverable Volume  \
# Date
# 2002-01-01  88.53   47087  4.168734e+11  105660.5             35559.0
# 2002-01-02  88.05   70982  6.249913e+11  105660.5             64128.0
# 2002-01-03  90.40  143055  1.293277e+12  105660.5            114325.0
# 2002-01-04  91.43   89792  8.209558e+11  105660.5             73659.0
# 2002-01-07  90.58  151344  1.370891e+12  105660.5            123531.0
#
#             %Deliverble  vwap_boxcox
# Date
# 2002-01-01       0.7552     6.692347
# 2002-01-02       0.9034     6.680796
# 2002-01-03       0.7992     6.736855
# 2002-01-04       0.8203     6.761044
# 2002-01-07       0.8162     6.741098

# %% [markdown]
# # Feature Engineering:
# Appling sliding window statistic on columns to obtain lag values, to be used in modelling the dataset. The mean and standard lag values of the features will be useful to forcast out of sample or test sample of VWAP.

# %%
df2.reset_index(drop=False,inplace=True)
lag_features = ["High", "Low", "Volume", "Turnover", "Trades"]
window1 = 3
window2 = 7
window3 = 30

df_rolled_3d = df2[lag_features].rolling(window=window1, min_periods=0)
df_rolled_7d = df2[lag_features].rolling(window=window2, min_periods=0)
df_rolled_30d = df2[lag_features].rolling(window=window3, min_periods=0)

df_mean_3d = df_rolled_3d.mean().shift(1).reset_index().astype(np.float32)
df_mean_7d = df_rolled_7d.mean().shift(1).reset_index().astype(np.float32)
df_mean_30d = df_rolled_30d.mean().shift(1).reset_index().astype(np.float32)

df_std_3d = df_rolled_3d.std().shift(1).reset_index().astype(np.float32)
df_std_7d = df_rolled_7d.std().shift(1).reset_index().astype(np.float32)
df_std_30d = df_rolled_30d.std().shift(1).reset_index().astype(np.float32)

for feature in lag_features:
    df2[f"{feature}_mean_lag{window1}"] = df_mean_3d[feature]
    df2[f"{feature}_mean_lag{window2}"] = df_mean_7d[feature]
    df2[f"{feature}_mean_lag{window3}"] = df_mean_30d[feature]
    
    df2[f"{feature}_std_lag{window1}"] = df_std_3d[feature]
    df2[f"{feature}_std_lag{window2}"] = df_std_7d[feature]
    df2[f"{feature}_std_lag{window3}"] = df_std_30d[feature]

df2.fillna(df.mean(), inplace=True)

df2.set_index("Date", drop=False, inplace=True)
df2.head()
# Out:
#                  Date     Symbol Series  Prev Close   Open   High    Low  \
# Date
# 2002-01-01 2002-01-01  ICICIBANK     EQ        88.7  89.95  89.95  87.30
# 2002-01-02 2002-01-02  ICICIBANK     EQ        88.5  88.00  89.00  87.50
# 2002-01-03 2002-01-03  ICICIBANK     EQ        88.4  86.60  92.95  86.60
# 2002-01-04 2002-01-04  ICICIBANK     EQ        92.0  92.50  93.20  90.00
# 2002-01-07 2002-01-07  ICICIBANK     EQ        91.1  91.00  92.50  89.25
#
#              Last  Close   VWAP  ...  Turnover_mean_lag30  Turnover_std_lag3  \
# Date                             ...
# 2002-01-01  88.05  88.50  88.53  ...                  NaN                NaN
# 2002-01-02  87.60  88.40  88.05  ...         4.168734e+11                NaN
# 2002-01-03  92.05  92.00  90.40  ...         5.209324e+11       1.471616e+11
# 2002-01-04  91.90  91.10  91.43  ...         7.783807e+11       4.578942e+11
# 2002-01-07  91.05  90.15  90.58  ...         7.890245e+11       3.435345e+11
#
#             Turnover_std_lag7  Turnover_std_lag30  Trades_mean_lag3  \
# Date
# 2002-01-01                NaN                 NaN               NaN
# 2002-01-02                NaN                 NaN          105660.5
# 2002-01-03       1.471616e+11        1.471616e+11          105660.5
# 2002-01-04       4.578942e+11        4.578942e+11          105660.5
# 2002-01-07       3.744746e+11        3.744746e+11          105660.5
#
#             Trades_mean_lag7  Trades_mean_lag30  Trades_std_lag3  \
# Date
# 2002-01-01               NaN                NaN              NaN
# 2002-01-02          105660.5           105660.5              NaN
# 2002-01-03          105660.5           105660.5              0.0
# 2002-01-04          105660.5           105660.5              0.0
# 2002-01-07          105660.5           105660.5              0.0
#
#             Trades_std_lag7  Trades_std_lag30
# Date
# 2002-01-01              NaN               NaN
# 2002-01-02              NaN               NaN
# 2002-01-03              0.0               0.0
# 2002-01-04              0.0               0.0
# 2002-01-07              0.0               0.0
#
# [5 rows x 46 columns]

# %% [markdown]
# Months and Days are useful features to input in the model for predictions.

# %%
df2.Date = pd.to_datetime(df2.Date, format="%Y-%m-%d")
df2["month"] = df2.Date.dt.month
df2["day"] = df2.Date.dt.day

# %% [markdown]
# # Preparing model
# Note: The additional features supplied to time series problems are called exogenous regressors.

# %%
df2.dropna(axis =0,inplace=True)
df2 =df2[~df2.isin([np.nan, np.inf, -np.inf]).any(1)]
df_train = df2[df2.Date < "2019"]
df_valid = df2[df2.Date >= "2019"]

exogenous_features = ["High_mean_lag3", "High_std_lag3", "Low_mean_lag3", "Low_std_lag3",
                      "Volume_mean_lag3", "Volume_std_lag3", "Turnover_mean_lag3",
                      "Turnover_std_lag3", "Trades_mean_lag3", "Trades_std_lag3",
                      "High_mean_lag7", "High_std_lag7", "Low_mean_lag7", "Low_std_lag7",
                      "Volume_mean_lag7", "Volume_std_lag7", "Turnover_mean_lag7",
                      "Turnover_std_lag7", "Trades_mean_lag7", "Trades_std_lag7",
                      "High_mean_lag30", "High_std_lag30", "Low_mean_lag30", "Low_std_lag30",
                      "Volume_mean_lag30", "Volume_std_lag30", "Turnover_mean_lag30",
                      "Turnover_std_lag30", "Trades_mean_lag30", "Trades_std_lag30",
                      "month", "day"]
#Dropping NULL or infinite values to avoid errors.

# %%
#Dataset with target variable and exogeneous features 
df3 = pd.DataFrame()
df3['VWAP'] = df2['VWAP']
for i in exogenous_features:
    df3[i] = df2[i]
print(pd.infer_freq(df3.index, warn=True))
df3=df3.resample('MS').sum()
# Out:
# None

# %% [markdown]
# # AutoRegressor:
# A model that uses the dependent relationship between an observation and some number of lagged observations.
# > "We can use statistical measures to calculate the correlation between the output variable and values at previous time steps at various different lags. The stronger the correlation between the output variable and a specific lagged variable, the more weight that autoregression model can put on that variable when modeling."-https://machinelearningmastery.com/autoregression-models-time-series-forecasting-python/<br>
#
# AR(1) model<br>
# Rt = μ + ϕRt-1 + εt<br>
#
# As RHS has only one lagged value(Rt-1)this is called AR model of order 1 where μ is mean and ε is noise at time t
# If ϕ = 1, it is random walk. Else if ϕ = 0, it is white noise. Else if -1 < ϕ < 1, it is stationary. If ϕ is -ve, there is men reversion. If ϕ is +ve, there is momentum.<br>
#
# AR(2) model<br>
# Rt = μ + ϕ1Rt-1 + ϕ2Rt-2 + εt<br>
#
# AR(3) model<br>
# Rt = μ + ϕ1Rt-1 + ϕ2Rt-2 + ϕ3Rt-3 + εt<br>

# %%
from statsmodels.tsa.ar_model import AutoReg
model = AutoReg(df3.VWAP,lags=3, exog=df3[exogenous_features])
res = model.fit()
print(res.summary())
print("μ={} ,ϕ={}".format(res.params[0],res.params[1]))
# Out:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                   VWAP   No. Observations:                  227
# Model:                   AutoReg-X(3)   Log Likelihood               -1202.940
# Method:               Conditional MLE   S.D. of innovations             52.005
# Date:                Fri, 08 Jan 2021   AIC                              8.233
# Time:                        14:15:55   BIC                              8.797
# Sample:                    04-01-2002   HQIC                             8.460
#                          - 11-01-2020
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# intercept              -0.0066      0.003     -2.399      0.016      -0.012      -0.001
# VWAP.L1                 0.0049      0.003      1.827      0.068      -0.000       0.010
# VWAP.L2                -0.0108      0.002     -4.324      0.000      -0.016      -0.006
# VWAP.L3                 0.0042      0.002      2.658      0.008       0.001       0.007
# High_mean_lag3          1.3142      0.037     35.515      0.000       1.242       1.387
# High_std_lag3           0.0951      0.062      1.535      0.125      -0.026       0.217
# Low_mean_lag3           1.1547      0.036     32.287      0.000       1.085       1.225
# Low_std_lag3            0.0276      0.035      0.791      0.429      -0.041       0.096
# Volume_mean_lag3     1.113e-06   9.92e-07      1.123      0.262    -8.3e-07    3.06e-06
# Volume_std_lag3     -2.187e-06   1.34e-06     -1.630      0.103   -4.82e-06    4.42e-07
# Turnover_mean_lag3  -7.342e-14    2.4e-14     -3.062      0.002    -1.2e-13   -2.64e-14
# Turnover_std_lag3    8.177e-14   2.74e-14      2.983      0.003     2.8e-14    1.35e-13
# Trades_mean_lag3        0.0002   6.82e-05      2.526      0.012    3.86e-05       0.000
# Trades_std_lag3     -5.766e-05      0.000     -0.564      0.573      -0.000       0.000
# High_mean_lag7         -0.7529      0.031    -24.030      0.000      -0.814      -0.691
# High_std_lag7           0.0853      0.038      2.233      0.026       0.010       0.160
# Low_mean_lag7          -0.7954      0.031    -25.336      0.000      -0.857      -0.734
# Low_std_lag7           -0.0379      0.050     -0.760      0.447      -0.136       0.060
# Volume_mean_lag7    -1.228e-06    1.1e-06     -1.112      0.266   -3.39e-06    9.37e-07
# Volume_std_lag7      2.374e-06   1.17e-06      2.032      0.042    8.41e-08    4.66e-06
# Turnover_mean_lag7   6.734e-14   2.84e-14      2.374      0.018    1.17e-14    1.23e-13
# Turnover_std_lag7   -7.608e-14   2.57e-14     -2.959      0.003   -1.26e-13   -2.57e-14
# Trades_mean_lag7       -0.0001   7.99e-05     -1.786      0.074      -0.000    1.39e-05
# Trades_std_lag7      1.637e-05   9.98e-05      0.164      0.870      -0.000       0.000
# High_mean_lag30        -0.1669      0.050     -3.346      0.001      -0.265      -0.069
# High_std_lag30         -0.1795      0.076     -2.373      0.018      -0.328      -0.031
# Low_mean_lag30          0.2495      0.050      5.000      0.000       0.152       0.347
# Low_std_lag30           0.1729      0.080      2.169      0.030       0.017       0.329
# Volume_mean_lag30    3.475e-07   3.37e-07      1.031      0.303   -3.13e-07    1.01e-06
# Volume_std_lag30    -7.525e-07   4.31e-07     -1.745      0.081    -1.6e-06    9.27e-08
# Turnover_mean_lag30 -3.315e-16   9.33e-15     -0.036      0.972   -1.86e-14     1.8e-14
# Turnover_std_lag30    1.81e-14   9.75e-15      1.856      0.064   -1.02e-15    3.72e-14
# Trades_mean_lag30   -2.549e-05    2.6e-05     -0.979      0.328   -7.65e-05    2.56e-05
# Trades_std_lag30     2.665e-06   3.33e-05      0.080      0.936   -6.26e-05    6.79e-05
# month                   0.0421      0.046      0.924      0.355      -0.047       0.131
# day                    -0.0434      0.057     -0.760      0.447      -0.155       0.069
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -2.2736           -5.3255j            5.7905           -0.3142
# AR.2           -2.2736           +5.3255j            5.7905            0.3142
# AR.3            7.1165           -0.0000j            7.1165           -0.0000
# -----------------------------------------------------------------------------
# μ=-0.006638050403960261 ,ϕ=0.004903071236595169

# %%
res = model.fit(cov_type="HC0")
print(res.summary())
print("μ={} ,ϕ={}".format(res.params[0],res.params[1]))
# Out:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                   VWAP   No. Observations:                  227
# Model:                   AutoReg-X(3)   Log Likelihood               -1202.940
# Method:               Conditional MLE   S.D. of innovations             52.005
# Date:                Fri, 08 Jan 2021   AIC                              8.233
# Time:                        14:15:55   BIC                              8.797
# Sample:                    04-01-2002   HQIC                             8.460
#                          - 11-01-2020
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# intercept              -0.0066      0.003     -2.435      0.015      -0.012      -0.001
# VWAP.L1                 0.0049      0.003      1.525      0.127      -0.001       0.011
# VWAP.L2                -0.0108      0.003     -3.489      0.000      -0.017      -0.005
# VWAP.L3                 0.0042      0.002      2.472      0.013       0.001       0.008
# High_mean_lag3          1.3142      0.047     28.115      0.000       1.223       1.406
# High_std_lag3           0.0951      0.082      1.164      0.244      -0.065       0.255
# Low_mean_lag3           1.1547      0.043     26.820      0.000       1.070       1.239
# Low_std_lag3            0.0276      0.044      0.632      0.527      -0.058       0.113
# Volume_mean_lag3     1.113e-06   1.03e-06      1.080      0.280   -9.08e-07    3.13e-06
# Volume_std_lag3     -2.187e-06   1.29e-06     -1.695      0.090   -4.72e-06    3.42e-07
# Turnover_mean_lag3  -7.342e-14   2.86e-14     -2.564      0.010    -1.3e-13   -1.73e-14
# Turnover_std_lag3    8.177e-14   2.85e-14      2.867      0.004    2.59e-14    1.38e-13
# Trades_mean_lag3        0.0002    7.6e-05      2.266      0.023    2.32e-05       0.000
# Trades_std_lag3     -5.766e-05      0.000     -0.565      0.572      -0.000       0.000
# High_mean_lag7         -0.7529      0.041    -18.527      0.000      -0.833      -0.673
# High_std_lag7           0.0853      0.048      1.768      0.077      -0.009       0.180
# Low_mean_lag7          -0.7954      0.041    -19.202      0.000      -0.877      -0.714
# Low_std_lag7           -0.0379      0.063     -0.598      0.550      -0.162       0.086
# Volume_mean_lag7    -1.228e-06   1.16e-06     -1.063      0.288   -3.49e-06    1.04e-06
# Volume_std_lag7      2.374e-06   1.16e-06      2.039      0.041    9.22e-08    4.65e-06
# Turnover_mean_lag7   6.734e-14   3.32e-14      2.025      0.043    2.17e-15    1.33e-13
# Turnover_std_lag7   -7.608e-14   2.77e-14     -2.750      0.006    -1.3e-13   -2.19e-14
# Trades_mean_lag7       -0.0001   9.01e-05     -1.585      0.113      -0.000    3.38e-05
# Trades_std_lag7      1.637e-05    9.8e-05      0.167      0.867      -0.000       0.000
# High_mean_lag30        -0.1669      0.056     -2.979      0.003      -0.277      -0.057
# High_std_lag30         -0.1795      0.100     -1.787      0.074      -0.376       0.017
# Low_mean_lag30          0.2495      0.057      4.373      0.000       0.138       0.361
# Low_std_lag30           0.1729      0.106      1.633      0.103      -0.035       0.380
# Volume_mean_lag30    3.475e-07   3.72e-07      0.933      0.351   -3.83e-07    1.08e-06
# Volume_std_lag30    -7.525e-07   3.87e-07     -1.946      0.052   -1.51e-06    5.54e-09
# Turnover_mean_lag30 -3.315e-16   1.07e-14     -0.031      0.975   -2.13e-14    2.06e-14
# Turnover_std_lag30    1.81e-14    9.7e-15      1.866      0.062   -9.14e-16    3.71e-14
# Trades_mean_lag30   -2.549e-05   2.43e-05     -1.050      0.293    -7.3e-05    2.21e-05
# Trades_std_lag30     2.665e-06   2.92e-05      0.091      0.927   -5.46e-05       6e-05
# month                   0.0421      0.046      0.913      0.361      -0.048       0.133
# day                    -0.0434      0.057     -0.765      0.444      -0.155       0.068
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -2.2736           -5.3255j            5.7905           -0.3142
# AR.2           -2.2736           +5.3255j            5.7905            0.3142
# AR.3            7.1165           -0.0000j            7.1165           -0.0000
# -----------------------------------------------------------------------------
# μ=-0.006638050403960261 ,ϕ=0.004903071236595169

# %%
fig = res.plot_predict('2020-07-01', '2020-11-01')
ax = df3['VWAP'].loc['2020-06-01':].plot(linewidth=4, linestyle=':', label='Actual VWAP')
plt.title('VWAP Forcast vs Actual: July 2020 - November 2020')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(16,9))
fig = res.plot_diagnostics(fig=fig, lags=30)

# %%
rmse = math.sqrt(mean_squared_error(df3['VWAP'].loc['2014-01-01':'2020-11-01'],res.predict(start='2014-01-01',end='2020-11-01') ))
print("The root mean squared error is {}.".format(rmse))
# Out:
# The root mean squared error is 32.3039225422259.

# %% [markdown]
# AutoRegressor has a good score! Now let's try ARIMA model. <br>
# Ref:  https://www.kaggle.com/rohanrao/a-modern-time-series-tutorial

# %% [markdown]
# # ARIMA Models
# An ARIMA model is a class of statistical models for analyzing and forecasting time series data. It explicitly caters to a suite of standard structures in time series data, and as such provides a simple yet powerful method for making skillful time series forecasts. ARIMA is an acronym that stands for AutoRegressive Integrated Moving Average.

# %%
pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-1.8.0-cp37-cp37m-manylinux1_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 1.3 MB/s eta 0:00:01
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (0.14.1)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (1.25.9)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (46.1.3.post20200325)
# Requirement already satisfied: pandas>=0.19 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (1.1.5)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (1.18.5)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (0.11.1)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (0.23.2)
# Collecting Cython<0.29.18,>=0.29
#   Downloading Cython-0.29.17-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 13.4 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.19->pmdarima) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (1.18.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.14.0)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (1.18.5)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.22->pmdarima) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (0.14.1)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (1.18.5)
# Requirement already satisfied: patsy>=0.5 in /opt/conda/lib/python3.7/site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Requirement already satisfied: pandas>=0.19 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (1.1.5)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (1.18.5)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (1.18.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.14.0)
# Installing collected packages: Cython, pmdarima
#   Attempting uninstall: Cython
#     Found existing installation: Cython 0.29.21
#     Uninstalling Cython-0.29.21:
#       Successfully uninstalled Cython-0.29.21
# Successfully installed Cython-0.29.17 pmdarima-1.8.0
# WARNING: You are using pip version 20.3.1; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from pmdarima.arima import auto_arima
model = auto_arima(df_train.VWAP, exogenous=df_train[exogenous_features], trace=True, error_action="ignore", suppress_warnings=True)
model.fit(df_train.VWAP, exogenous=df_train[exogenous_features])

forecast = model.predict(n_periods=len(df_valid), exogenous=df_valid[exogenous_features])
df_valid["Forecast_ARIMAX"] = forecast
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=40118.945, Time=14.07 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=40953.311, Time=6.04 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=40261.305, Time=7.11 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=40171.100, Time=9.59 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=71875.679, Time=6.13 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=40177.383, Time=12.21 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=40123.290, Time=11.06 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=40118.495, Time=12.90 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=40133.797, Time=11.66 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=40120.499, Time=12.49 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=40120.496, Time=14.18 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=40119.933, Time=12.71 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=40120.300, Time=13.65 sec
#  ARIMA(4,0,3)(0,0,0)[0] intercept   : AIC=40122.503, Time=13.04 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=40116.495, Time=12.10 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=40116.945, Time=12.94 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=40131.797, Time=11.12 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=40118.499, Time=12.02 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=40118.496, Time=12.31 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=40121.290, Time=9.26 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=40117.932, Time=12.48 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=40118.300, Time=11.91 sec
#  ARIMA(4,0,3)(0,0,0)[0]             : AIC=40120.502, Time=11.70 sec
#
# Best model:  ARIMA(3,0,2)(0,0,0)[0]
# Total fit time: 262.734 seconds
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.

# %%
df_valid[["VWAP", "Forecast_ARIMAX"]].plot(figsize=(14, 7))

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

print("RMSE of Auto ARIMAX:", np.sqrt(mean_squared_error(df_valid.VWAP, df_valid.Forecast_ARIMAX)))
print("\nMAE of Auto ARIMAX:", mean_absolute_error(df_valid.VWAP, df_valid.Forecast_ARIMAX))
# Out:
# RMSE of Auto ARIMAX: 19.253930585676756
#
# MAE of Auto ARIMAX: 11.224113298015231

# %% [markdown]
# AUTOARIMAX does a good job in forcasting VWAP, and the rmse score is less than autoregressor. Hence ARIMA is the best model perhaps. Let's check for SARIMA model next!
